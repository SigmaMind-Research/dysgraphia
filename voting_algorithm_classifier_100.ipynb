# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
#Evaluvating
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,RocCurveDisplay,precision_score,recall_score,f1_score,ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split,RandomizedSearchCV,GridSearchCV,cross_val_score
from sklearn.ensemble import VotingClassifier

# %%
from sklearn.svm import SVC

# %%
features=pd.read_csv('/content/drive/MyDrive/feature_100_true.csv')

# %%
features
# Out:
#      Pen Pressure  Line Spacing  Slant Angle  Baseline angle  \
# 0       28.944342   1106.960000            5        0.000000
# 1       43.559691    617.000000            5        0.000000
# 2       87.790334   2186.500000            5     1363.664609
# 3       86.561794    602.000000           -5        0.000000
# 4       61.942587    701.352041           -5        0.000000
# ..            ...           ...          ...             ...
# 201    308.400209    210.000000            5       23.482151
# 202    549.311920    160.000000            5       97.446474
# 203     12.188425  32473.760000            5        0.000000
# 204      0.086254    899.000000            5        0.000000
# 205    135.671924      0.000000           -5      329.415768
#
#                                                   Link lable        l1  \
# 0    /content/drive/MyDrive/data/Normal/dysgraphia_...    no -1.111134
# 1    /content/drive/MyDrive/data/Normal/dysgraphia_...    no -1.082647
# 2    /content/drive/MyDrive/data/Normal/dysgraphia_...    no -1.183598
# 3    /content/drive/MyDrive/data/Normal/dysgraphia_...    no -1.097709
# 4    /content/drive/MyDrive/data/Normal/dysgraphia_...    no -1.269350
# ..                                                 ...   ...       ...
# 201  /content/drive/MyDrive/data/Dysgraphia/dysgrap...   yes -2.470516
# 202  /content/drive/MyDrive/data/Dysgraphia/dysgrap...   yes -2.504734
# 203  /content/drive/MyDrive/data/Dysgraphia/dysgrap...   yes -2.210393
# 204  /content/drive/MyDrive/data/Dysgraphia/dysgrap...   yes -2.233008
# 205  /content/drive/MyDrive/data/Dysgraphia/dysgrap...   yes -2.659174
#
#             l2        l3        l4        l5        l6        l7         l8
# 0     2.815558 -1.963040 -0.453976 -0.714596  5.369467 -1.070979  -1.788626
# 1     3.269634 -1.901758 -0.508880 -0.687258  5.052329 -1.058053  -1.636201
# 2     2.349073 -2.086748 -0.382516 -0.695264  6.111055 -1.161153  -2.142544
# 3     3.170597 -1.899564 -0.520904 -0.703620  5.084200 -1.051114  -1.654392
# 4     2.046691 -2.122050 -0.381242 -0.751105  6.334366 -1.142994  -2.280844
# ..         ...       ...       ...       ...       ...       ...        ...
# 201  11.562148  2.190010 -1.462264 -2.349383 -0.382875 -0.764947  14.053461
# 202  11.576081  1.995893 -1.411055 -2.212195 -0.285212 -0.695404  13.706995
# 203   9.209371  0.707892 -0.966253 -1.476118 -0.128085 -0.404649   7.830327
# 204  10.107451  1.766552 -1.166585 -2.060947 -0.289563 -0.524454  11.425462
# 205  12.040603  2.397348 -1.543056 -2.552639 -0.426635 -0.817882  14.874842
#
# [206 rows x 14 columns]

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Pen Pressure    206 non-null    float64
#  1   Line Spacing    206 non-null    float64
#  2   Slant Angle     206 non-null    int64
#  3   Baseline angle  206 non-null    float64
#  4   Link            206 non-null    object
#  5   lable           206 non-null    object
#  6   l1              206 non-null    float64
#  7   l2              206 non-null    float64
#  8   l3              206 non-null    float64
#  9   l4              206 non-null    float64
#  10  l5              206 non-null    float64
#  11  l6              206 non-null    float64
#  12  l7              206 non-null    float64
#  13  l8              206 non-null    float64
# dtypes: float64(11), int64(1), object(2)
# memory usage: 22.7+ KB

# %%
labels=features['lable']
features.drop(['Link','lable'],axis=1,inplace=True)

# %%
features
# Out:
#      Pen Pressure  Line Spacing  Slant Angle  Baseline angle        l1  \
# 0       28.944342   1106.960000            5        0.000000 -1.111134
# 1       43.559691    617.000000            5        0.000000 -1.082647
# 2       87.790334   2186.500000            5     1363.664609 -1.183598
# 3       86.561794    602.000000           -5        0.000000 -1.097709
# 4       61.942587    701.352041           -5        0.000000 -1.269350
# ..            ...           ...          ...             ...       ...
# 201    308.400209    210.000000            5       23.482151 -2.470516
# 202    549.311920    160.000000            5       97.446474 -2.504734
# 203     12.188425  32473.760000            5        0.000000 -2.210393
# 204      0.086254    899.000000            5        0.000000 -2.233008
# 205    135.671924      0.000000           -5      329.415768 -2.659174
#
#             l2        l3        l4        l5        l6        l7         l8
# 0     2.815558 -1.963040 -0.453976 -0.714596  5.369467 -1.070979  -1.788626
# 1     3.269634 -1.901758 -0.508880 -0.687258  5.052329 -1.058053  -1.636201
# 2     2.349073 -2.086748 -0.382516 -0.695264  6.111055 -1.161153  -2.142544
# 3     3.170597 -1.899564 -0.520904 -0.703620  5.084200 -1.051114  -1.654392
# 4     2.046691 -2.122050 -0.381242 -0.751105  6.334366 -1.142994  -2.280844
# ..         ...       ...       ...       ...       ...       ...        ...
# 201  11.562148  2.190010 -1.462264 -2.349383 -0.382875 -0.764947  14.053461
# 202  11.576081  1.995893 -1.411055 -2.212195 -0.285212 -0.695404  13.706995
# 203   9.209371  0.707892 -0.966253 -1.476118 -0.128085 -0.404649   7.830327
# 204  10.107451  1.766552 -1.166585 -2.060947 -0.289563 -0.524454  11.425462
# 205  12.040603  2.397348 -1.543056 -2.552639 -0.426635 -0.817882  14.874842
#
# [206 rows x 12 columns]

# %%
ig,ax=plt.subplots(figsize=(10,10))
mp=ax.scatter(features['Pen Pressure'],features['Baseline angle'])
#mp=ax.scatter(dk.age[dk.cp==0],dk.trestbps[dk.cp==0])
ax.legend
ax.set(xlabel="Pen Pressure",ylabel="Baseline angle")
# Out:
# [Text(0.5, 0, 'Pen Pressure'), Text(0, 0.5, 'Baseline angle')]

# %%
ig,ax=plt.subplots(figsize=(10,10))
mp=ax.scatter(features['Slant Angle'],features['Baseline angle'])

ax.legend
ax.set(xlabel="Slant angle",ylabel="Baseline angle")
# Out:
# [Text(0.5, 0, 'Slant angle'), Text(0, 0.5, 'Baseline angle')]

# %%
features.corr()
# Out:
#                 Pen Pressure  Line Spacing  Slant Angle  Baseline angle  \
# Pen Pressure        1.000000     -0.100115    -0.037254        0.160411
# Line Spacing       -0.100115      1.000000    -0.035870       -0.037531
# Slant Angle        -0.037254     -0.035870     1.000000       -0.011291
# Baseline angle      0.160411     -0.037531    -0.011291        1.000000
# l1                 -0.379614      0.022608    -0.113088       -0.255012
# l2                  0.377653     -0.005197     0.092449        0.266503
# l3                  0.383667     -0.024523     0.097602        0.272545
# l4                 -0.369911      0.021722    -0.101527       -0.257733
# l5                 -0.378088      0.032742    -0.103165       -0.269727
# l6                 -0.341454     -0.016334    -0.099271       -0.258501
# l7                  0.153182      0.069362     0.071761        0.156522
# l8                  0.392611     -0.019801     0.090370        0.281102
#
#                       l1        l2        l3        l4        l5        l6  \
# Pen Pressure   -0.379614  0.377653  0.383667 -0.369911 -0.378088 -0.341454
# Line Spacing    0.022608 -0.005197 -0.024523  0.021722  0.032742 -0.016334
# Slant Angle    -0.113088  0.092449  0.097602 -0.101527 -0.103165 -0.099271
# Baseline angle -0.255012  0.266503  0.272545 -0.257733 -0.269727 -0.258501
# l1              1.000000 -0.916508 -0.950642  0.924590  0.978108  0.803957
# l2             -0.916508  1.000000  0.987263 -0.992311 -0.955408 -0.963850
# l3             -0.950642  0.987263  1.000000 -0.988496 -0.982620 -0.925208
# l4              0.924590 -0.992311 -0.988496  1.000000  0.964952  0.942864
# l5              0.978108 -0.955408 -0.982620  0.964952  1.000000  0.863321
# l6              0.803957 -0.963850 -0.925208  0.942864  0.863321  1.000000
# l7             -0.275674  0.559618  0.463418 -0.498247 -0.345627 -0.748459
# l8             -0.954165  0.986866  0.996159 -0.986078 -0.987269 -0.920438
#
#                       l7        l8
# Pen Pressure    0.153182  0.392611
# Line Spacing    0.069362 -0.019801
# Slant Angle     0.071761  0.090370
# Baseline angle  0.156522  0.281102
# l1             -0.275674 -0.954165
# l2              0.559618  0.986866
# l3              0.463418  0.996159
# l4             -0.498247 -0.986078
# l5             -0.345627 -0.987269
# l6             -0.748459 -0.920438
# l7              1.000000  0.455670
# l8              0.455670  1.000000

# %%
fig,ax=plt.subplots(figsize=(15,15))
ax=sns.heatmap(data=features.corr(),annot=True)

# %%
def mdlscr(model,x_tr,x_t,y_tr,y_t):
     model.fit(x_tr,y_tr)
     print(model.score(x_t,y_t))
     return model

# %%
ans={}
np.random.seed(42)
x_train,x_test,y_train,y_test=train_test_split(features,labels,train_size=0.9)
print("random forest classifier")
ans["RandomForestClassifier_all"]=mdlscr(RandomForestClassifier(),x_train,x_test,y_train,y_test)
print("Logistic Regression")
ans["LogisticRegression_all"]=mdlscr(LogisticRegression(max_iter=1000),x_train,x_test,y_train,y_test)
print("kNeighbour")
ans["kNeighbour_all"]=mdlscr(KNeighborsClassifier(),x_train,x_test,y_train,y_test)
print("Decision Tree")
ans["dtree_all"]=mdlscr(DecisionTreeClassifier(),x_train,x_test,y_train,y_test)
# Out:
# random forest classifier
# 0.9523809523809523
# Logistic Regression
# 0.8571428571428571
# kNeighbour
# 0.8571428571428571
# Decision Tree
# 1.0

# %%
voting_classifier_hard = VotingClassifier(
    estimators = [('dtc',DecisionTreeClassifier()),
                  ('lr', LogisticRegression(max_iter=1000)),
                  ('rf',RandomForestClassifier() ),
                  ('Knb',KNeighborsClassifier() )
                  ],
    voting='hard')
voting_classifier_soft = VotingClassifier(
    estimators = [('dtc',DecisionTreeClassifier()),
                  ('lr', LogisticRegression(max_iter=1000)),
                  ('rf',RandomForestClassifier() ),
                  ('Knb',KNeighborsClassifier() )
                  ],
    voting='soft')

# %%
 voting_classifier_soft.fit(x_train,y_train)
 print(voting_classifier_soft.score(x_test,y_test))
# Out:
# 1.0

# %%
 voting_classifier_hard.fit(x_train,y_train)
 print(voting_classifier_soft.score(x_test,y_test))
# Out:
# 1.0

# %%
def evaluvate(model,x,y):
    y_predict=model.predict(x)
    print(classification_report(y,y_predict))
    ConfusionMatrixDisplay.from_predictions(y,y_predict)

# %%
evaluvate(voting_classifier_soft,x_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#           no       1.00      1.00      1.00        11
#          yes       1.00      1.00      1.00        10
#
#     accuracy                           1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21

# %%
evaluvate(voting_classifier_hard,x_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#           no       0.92      1.00      0.96        11
#          yes       1.00      0.90      0.95        10
#
#     accuracy                           0.95        21
#    macro avg       0.96      0.95      0.95        21
# weighted avg       0.96      0.95      0.95        21
